# %% [markdown]
# En este notebook se calcula la decisión óptima del problema de valoración de activos para los casos con n = 1, 2, ... , 10 observaciones. Para ello, se ejecuta el código que devuelve la decisión óptima 5 veces para calcular la media y la desviación típica de las mismas.

# %%
# Importamos las librerías necesarias
from scipy.stats import norm, truncnorm
import numpy as np
from scipy.optimize import minimize
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt
from math import sqrt

# Importamos el código a ejecutar para el cálculo de la decisión óptima. La función valoracion_activos recibe como
# parámetro el número de observaciones y devuelve la decisión óptima para ese número de observaciones.
from valoracion_activos import valoracion_activos

# %%
for num_obs in range(1,11):
    print(num_obs)
    valoracion_activos(num_obs)
# Out:
# 1
# La decisión óptima con  1 observaciones es comprar cuando y >  11.307016666666666
# 2
# La decisión óptima con  2 observaciones es comprar cuando y >  11.227416666666667
# 3
# La decisión óptima con  3 observaciones es comprar cuando y >  11.237366666666667
# 4
# La decisión óptima con  4 observaciones es comprar cuando y >  11.207516666666667
# 5
# La decisión óptima con  5 observaciones es comprar cuando y >  11.267216666666666
# 6
# La decisión óptima con  6 observaciones es comprar cuando y >  11.366716666666665
# 7
# La decisión óptima con  7 observaciones es comprar cuando y >  11.200883333333332
# 8
# La decisión óptima con  8 observaciones es comprar cuando y >  11.177666666666665
# 9
# La decisión óptima con  9 observaciones es comprar cuando y >  11.297066666666666
# 10
# La decisión óptima con  10 observaciones es comprar cuando y >  11.2838

# %%
for num_obs in range(1,11):
    print(num_obs)
    valoracion_activos(num_obs)
# Out:
# 1
# La decisión óptima con  1 observaciones es comprar cuando y >  11.220783333333333
# 2
# La decisión óptima con  2 observaciones es comprar cuando y >  11.277166666666666
# 3
# La decisión óptima con  3 observaciones es comprar cuando y >  11.2639
# 4
# La decisión óptima con  4 observaciones es comprar cuando y >  11.287116666666666
# 5
# La decisión óptima con  5 observaciones es comprar cuando y >  11.333549999999999
# 6
# La decisión óptima con  6 observaciones es comprar cuando y >  11.287116666666666
# 7
# La decisión óptima con  7 observaciones es comprar cuando y >  11.227416666666667
# 8
# La decisión óptima con  8 observaciones es comprar cuando y >  11.177666666666665
# 9
# La decisión óptima con  9 observaciones es comprar cuando y >  11.230733333333333
# 10
# La decisión óptima con  10 observaciones es comprar cuando y >  11.200883333333332

# %%
for num_obs in range(1,11):
    print(num_obs)
    valoracion_activos(num_obs)
# Out:
# 1
# La decisión óptima con  1 observaciones es comprar cuando y >  11.177666666666665
# 2
# La decisión óptima con  2 observaciones es comprar cuando y >  11.23405
# 3
# La decisión óptima con  3 observaciones es comprar cuando y >  11.29375
# 4
# La decisión óptima con  4 observaciones es comprar cuando y >  11.267216666666666
# 5
# La decisión óptima con  5 observaciones es comprar cuando y >  11.250633333333333
# 6
# La decisión óptima con  6 observaciones es comprar cuando y >  11.207516666666667
# 7
# La decisión óptima con  7 observaciones es comprar cuando y >  11.237366666666667
# 8
# La decisión óptima con  8 observaciones es comprar cuando y >  11.310333333333332
# 9
# La decisión óptima con  9 observaciones es comprar cuando y >  11.2838
# 10
# La decisión óptima con  10 observaciones es comprar cuando y >  11.350133333333332

# %%
for num_obs in range(1,11):
    print(num_obs)
    valoracion_activos(num_obs)
# Out:
# 1
# La decisión óptima con  1 observaciones es comprar cuando y >  11.204199999999998
# 2
# La decisión óptima con  2 observaciones es comprar cuando y >  11.25395
# 3
# La decisión óptima con  3 observaciones es comprar cuando y >  11.2838
# 4
# La decisión óptima con  4 observaciones es comprar cuando y >  11.343499999999999
# 5
# La decisión óptima con  5 observaciones es comprar cuando y >  11.297066666666666
# 6
# La decisión óptima con  6 observaciones es comprar cuando y >  11.300383333333333
# 7
# La decisión óptima con  7 observaciones es comprar cuando y >  11.353449999999999
# 8
# La decisión óptima con  8 observaciones es comprar cuando y >  11.171033333333332
# 9
# La decisión óptima con  9 observaciones es comprar cuando y >  11.237366666666667
# 10
# La decisión óptima con  10 observaciones es comprar cuando y >  11.260583333333333

# %%
for num_obs in range(1,11):
    print(num_obs)
    valoracion_activos(num_obs)
# Out:
# 1
# La decisión óptima con  1 observaciones es comprar cuando y >  11.144499999999999
# 2
# La decisión óptima con  2 observaciones es comprar cuando y >  11.240683333333333
# 3
# La decisión óptima con  3 observaciones es comprar cuando y >  11.2241
# 4
# La decisión óptima con  4 observaciones es comprar cuando y >  11.3037
# 5
# La decisión óptima con  5 observaciones es comprar cuando y >  11.313649999999999
# 6
# La decisión óptima con  6 observaciones es comprar cuando y >  11.27385
# 7
# La decisión óptima con  7 observaciones es comprar cuando y >  11.270533333333333
# 8
# La decisión óptima con  8 observaciones es comprar cuando y >  11.277166666666666
# 9
# La decisión óptima con  9 observaciones es comprar cuando y >  11.267216666666666
# 10
# La decisión óptima con  10 observaciones es comprar cuando y >  11.230733333333333
