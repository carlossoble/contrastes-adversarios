# %%
# Importamos las librerías necesarias
import random
from scipy.stats import norm
import numpy as np
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# Importamos el código a ejecutar para el cálculo de la decisión óptima.
from problema_rutas import problema_rutas, problema_rutas_sin_perdida

# %%
# Ejecutamos el problema 5 veces para calcular la media y desviación típica de los resultados
for n in range(5):
    problema_rutas()
# Out:
# La decisión óptima es pagar el peaje cuando y >  78.0  minutos.
# La decisión óptima es pagar el peaje cuando y >  77.75  minutos.
# La decisión óptima es pagar el peaje cuando y >  77.75  minutos.
# La decisión óptima es pagar el peaje cuando y >  77.5  minutos.
# La decisión óptima es pagar el peaje cuando y >  76.75  minutos.

# %%
# Ejecutamos el problema sin función de pérdida para obtener la probabilidad p_D(theta > theta_0 | y) para cada valor de y.
problema_rutas_sin_perdida()
# Out:
# Rechazo la idea de pagar el peaje con \alpha = 0,05 cuando y <  53.8526282853567  minutos.
# Rechazo la idea de pagar el peaje con \alpha = 0,1 cuando y <  56.476533166458076  minutos.
